# %% [markdown]
# # Task 3 Solution

# %% [markdown]
# ### By Vishnu Derkar
#
# ## Q.From Iris Dataset create a decision tree and visualize

# %%
#import all the relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import matplotlib as mtl
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Forming the iris dataframe 
iris = load_iris()
df = pd.DataFrame(iris.data , columns= iris.feature_names)
print("The values of Iris data is\n")
print(df.head())


y=pd.DataFrame(iris.target)
print("\n\nThe targets values of Iris is\n")
y.head()
# Out:
# The values of Iris data is
#
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#
# The targets values of Iris is
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %% [markdown]
# ## Data Visualization

# %%
sns.heatmap(df.corr(), cmap='Blues',square=False,linewidths=1)

# %%
sns.pairplot(data= df, diag_kind='kde')

# %%
plt.figure()
plt.subplot(221)
plt.boxplot(df.iloc[0])
plt.subplot(222)
plt.boxplot(df.iloc[1])
plt.subplot(223)
plt.boxplot(df.iloc[2])
plt.subplot(224)
plt.boxplot(df.iloc[3])

plt.show()

# %%
for class_number in np.unique(iris.target):
 plt.figure(1)
 df['sepal length (cm)'].iloc[np.where(iris.target ==
class_number)[0]].hist(bins=30)

# %%
for class_number in np.unique(iris.target):
 plt.figure(1)
 df['sepal width (cm)'].iloc[np.where(iris.target ==
class_number)[0]].hist(bins=30)

# %%
for class_number in np.unique(iris.target):
 plt.figure(1)
 df['petal length (cm)'].iloc[np.where(iris.target ==
class_number)[0]].hist(bins=30)

# %%
    
for class_number in np.unique(iris.target):
 plt.figure(1)
 df['petal width (cm)'].iloc[np.where(iris.target ==
class_number)[0]].hist(bins=30)

# %% [markdown]
# ## Let's make Decision Tree

# %%
# Defining the decision tree algorithm
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)

print("Decision Tree is ready")
# Out:
# Decision Tree is ready

# %% [markdown]
# ## Now let's Visualiza the Decision Tree

# %%
# Import necessary libraries for graph viz
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# # Here there is another Decision Tree

# %%
import pandas as pd
import numpy as np
from sklearn import tree
import pydotplus
from IPython.display import Image
from six import StringIO


X = df[df.columns[:-1]]
y = df[df.columns[-1]]

dtr = tree.DecisionTreeRegressor(max_depth=3)
dtr.fit(X, y)

dot_data = StringIO()  
tree.export_graphviz(dtr, out_file=dot_data, feature_names=X.columns)  

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
